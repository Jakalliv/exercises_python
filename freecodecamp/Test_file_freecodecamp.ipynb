# %%
x = 4
hanoi_towers = [list(range(x,0,-1)), [], []]
print(hanoi_towers)
print(hanoi_towers[0][0], hanoi_towers[1], hanoi_towers[2])
# Out:
# [[4, 3, 2, 1], [], []]
# 4 [] []

# %%
import merge_sort_algorithm

merge_sort([1,24,63,623,23])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import merge_sort_algorithm
# ----> 3 merge_sort([1,24,63,623,23])
#
# NameError: name 'merge_sort' is not defined
